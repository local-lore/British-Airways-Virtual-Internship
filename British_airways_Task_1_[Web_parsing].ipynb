# %% [markdown]
# There are mainly two ways to extract data from a website:
#
# - Use the API of the website (if it exists). For example, Facebook has the Facebook Graph API which allows retrieval of data posted on Facebook.
# - Access the HTML of the webpage and extract useful information/data from it. This technique is called web scraping or web harvesting or web data extraction.

# %% [markdown]
# The steps involved in web scraping using the implementation of a Web Scraping framework of Python called Beautiful Soup. Steps involved in web scraping:
#
# 1. Send an HTTP request to the URL of the webpage you want to access. The server responds to the request by returning the HTML content of the webpage. For this task, we will use a third-party HTTP library for python-requests.
# 2. Once we have accessed the HTML content, we are left with the task of parsing the data. Since most of the HTML data is nested, we cannot extract data simply through string processing. One needs a parser which can create a nested/tree structure of the HTML data. There are many HTML parser libraries available but the most advanced one is html5lib.
# 3. Now, all we need to do is navigating and searching the parse tree that we created, i.e. tree traversal. For this task, we will be using another third-party python library, Beautiful Soup. It is a Python library for pulling data out of HTML and XML files.

# %% [markdown]
# ##Install required libraries

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ##Searching and navigating through the parse tree

# %%
def parse_reviews(url):
  response = requests.get(url)
  soup = BeautifulSoup(response.content, 'html5lib')
  reviews = []
  for review in soup.find_all('article', attrs={'itemprop':'review'}):
    review_content = review.find('div', class_= 'text_content').get_text(strip = True).split('|')[1]
    date = review.find('time').get('datetime')
    verification = review.find('div', class_= 'text_content').get_text(strip = True).split('|')[0].replace('✅', '')

    rating = review.find('div', class_= 'rating-10')
    if rating:
      rating_value = rating.find('span', itemprop = 'ratingValue').get_text(strip=True)
    else:
      rating_value = None

    impression = review.find('h2', class_='text_header').get_text(strip=True) if review.find('h2', class_='text_header') else None

    author_info = review.find('h3', class_ = 'text_sub_header userStatusWrapper')
    if author_info:
      country = author_info.get_text(strip=True).split('(')[-1].split(')')[0]
    else:
      country = None

    content = {}
    for row in review.find_all('tr'):
      header = row.find('td', class_ = 'review-rating-header')
      value = row.find('td', class_ = 'review-value')
      stars = row.find_all('span', class_ = 'star fill')

      if header and (value or stars):
        header_text = header.get_text(strip=True)
        if value:
          content[header_text] = value.get_text(strip=True)
        elif stars:
          content[header_text] = len(stars)

      reviews_data = {'Date': date,
                      'Overall Rating' : rating_value,
                      'Country' : country,
                      'Impression' : impression,
                      'Verification' : verification,
                      'Review' : review_content,
                      **content}
    reviews.append(reviews_data)
  return reviews

# %% [markdown]
# ##Parsing the HTML content

# %% [markdown]
# A really nice thing about the BeautifulSoup library is that it is built on the top of the HTML parsing libraries like html5lib, lxml, html.parser, etc. So BeautifulSoup object and specify the parser library can be created at the same time.

# %%
def parse_multiple_pages(base_url, num_pages=10):
    df = pd.DataFrame()

    for i in range(1, num_pages + 1):
        url = f'{base_url}/page/{i}/?sortby=post_date&pagesize=100'
        page_review = pd.DataFrame(parse_reviews(url))
        df = pd.concat([df, page_review], axis=0).reset_index(drop=True)
    return df

base_url = 'https://www.airlinequality.com/airline-reviews/british-airways'
df = parse_multiple_pages(base_url, num_pages=10)

# %%
df.dtypes
# Out:
# Date                       object
# Overall Rating             object
# Country                    object
# Impression                 object
# Verification               object
# Review                     object
# Aircraft                   object
# Type Of Traveller          object
# Seat Type                  object
# Route                      object
# Date Flown                 object
# Seat Comfort              float64
# Cabin Staff Service       float64
# Food & Beverages          float64
# Inflight Entertainment    float64
# Ground Service            float64
# Wifi & Connectivity       float64
# Value For Money             int64
# Recommended                object
# dtype: object

# %%
columns_to_convert = ['Overall Rating', 'Seat Comfort', 'Cabin Staff Service', 'Food & Beverages', 'Inflight Entertainment', 'Ground Service', 'Wifi & Connectivity', 'Value For Money']
df[columns_to_convert] = df[columns_to_convert].apply(pd.to_numeric, errors = 'coerce')
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.head(10)
# Out:
#         Date  Overall Rating         Country  \
# 0 2024-10-14               1    South Africa
# 1 2024-10-12               6  United Kingdom
# 2 2024-10-12               1         Germany
# 3 2024-10-12               2   United States
# 4 2024-10-09               1    South Africa
# 5 2024-10-08               8  United Kingdom
# 6 2024-10-06               4  United Kingdom
# 7 2024-10-05               1   United States
# 8 2024-10-04               4           India
# 9 2024-09-28               5  United Kingdom
#
#                                           Impression   Verification  \
# 0                                “Appalling service”  Trip Verified
# 1                       “BA’s petty penny pinching ”  Trip Verified
# 2                “British arrogance with no manners”  Trip Verified
# 3                        "Terrible customer service"  Trip Verified
# 4                          “left much to be desired”  Trip Verified
# 5                      "crew were all very friendly"  Trip Verified
# 6                           "Simply not good enough"   Not Verified
# 7                       “BA refuses to reimburse us”  Trip Verified
# 8                            "my luggage is missing"  Trip Verified
# 9  "work is needed to provide a better customer e...  Trip Verified
#
#                                               Review           Aircraft  \
# 0     Appalling service with failing defective fl...               A380
# 1   British Airways charge you for the pleasure o...     Boeing 787-900
# 2   What is wrong with you guys? People pay lots ...              A320N
# 3     We booked two business class seat with Brit...                NaN
# 4   I’ve flown with many airlines, but my recent ...                NaN
# 5     I recently flew from New York back to Londo...  Boeing 777-336 ER
# 6     BA business class in Europe has a seat the ...                NaN
# 7   Our flight started in Seattle Wa heading to L...                NaN
# 8     British Airways Flight from Edinburgh got d...                NaN
# 9     British Airways World Traveller Plus (Premi...               A350
#
#   Type Of Traveller        Seat Type  \
# 0          Business   Business Class
# 1          Business   Business Class
# 2    Couple Leisure   Business Class
# 3    Couple Leisure   Business Class
# 4      Solo Leisure    Economy Class
# 5      Solo Leisure  Premium Economy
# 6      Solo Leisure   Business Class
# 7    Couple Leisure    Economy Class
# 8      Solo Leisure    Economy Class
# 9      Solo Leisure  Premium Economy
#
#                                         Route      Date Flown  Seat Comfort  \
# 0                      Johannesburg to London    October 2024           2.0
# 1                       London to Mexico City    October 2024           1.0
# 2                   Berlin to London Heathrow    October 2024           1.0
# 3             London Heathrow to Philadelphia  September 2024           1.0
# 4  Johannesburg to New York City via Heathrow    October 2024           5.0
# 5             New York JFK to London Heathrow    October 2024           5.0
# 6                          Antalya to Gatwick    October 2024           1.0
# 7                            London to Lisbon  September 2024           3.0
# 8               Edinburgh to Delhi via London  September 2024           1.0
# 9                         London to Vancouver  September 2024           4.0
#
#    Cabin Staff Service  Food & Beverages  Inflight Entertainment  \
# 0                  1.0               2.0                     2.0
# 1                  5.0               1.0                     1.0
# 2                  1.0               1.0                     NaN
# 3                  1.0               1.0                     NaN
# 4                  4.0               3.0                     2.0
# 5                  5.0               3.0                     5.0
# 6                  2.0               4.0                     NaN
# 7                  2.0               1.0                     1.0
# 8                  1.0               1.0                     NaN
# 9                  5.0               2.0                     1.0
#
#    Ground Service  Wifi & Connectivity  Value For Money Recommended
# 0             1.0                  2.0                1          no
# 1             2.0                  2.0                3         yes
# 2             2.0                  NaN                1          no
# 3             1.0                  1.0                1          no
# 4             3.0                  1.0                2          no
# 5             5.0                  NaN                4         yes
# 6             2.0                  1.0                2          no
# 7             1.0                  1.0                2          no
# 8             1.0                  NaN                1          no
# 9             3.0                  NaN                2         yes

# %%
df.to_csv('british_airways_reviews.csv', index=False)
